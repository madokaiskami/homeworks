# %%
# !wget -c https://repo.continuum.io/miniconda/Miniconda3-py39_23.5.2-0-Linux-x86_64.sh
# !chmod +x Miniconda3-py39_23.5.2-0-Linux-x86_64.sh
# !time bash ./Miniconda3-py39_23.5.2-0-Linux-x86_64.sh -b -f -p /usr/local
# Out:
# --2024-12-22 14:09:36--  https://repo.continuum.io/miniconda/Miniconda3-py39_23.5.2-0-Linux-x86_64.sh
# Resolving repo.continuum.io (repo.continuum.io)... 104.18.176.84, 104.18.177.84, 2606:4700::6812:b154, ...
# Connecting to repo.continuum.io (repo.continuum.io)|104.18.176.84|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://repo.anaconda.com/miniconda/Miniconda3-py39_23.5.2-0-Linux-x86_64.sh [following]
# --2024-12-22 14:09:36--  https://repo.anaconda.com/miniconda/Miniconda3-py39_23.5.2-0-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.191.158, 104.16.32.241, 2606:4700::6810:20f1, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.191.158|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 93409434 (89M) [application/x-sh]
# Saving to: ‘Miniconda3-py39_23.5.2-0-Linux-x86_64.sh’
#
# Miniconda3-py39_23. 100%[===================>]  89.08M  49.5MB/s    in 1.8s
#
# ...

# %%
# !python --version
# Out:
# Python 3.9.17

# %%
# !git clone https://github.com/Mu-Y/mpl-mdd.git
# !cd mpl-mdd && git submodule update --init --recursive
# Out:
# Cloning into 'mpl-mdd'...
# remote: Enumerating objects: 37, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 37 (delta 14), reused 26 (delta 11), pack-reused 0 (from 0)
# Receiving objects: 100% (37/37), 23.24 KiB | 23.24 MiB/s, done.
# Resolving deltas: 100% (14/14), done.
# Submodule 'speechbrain' (https://github.com/Mu-Y/speechbrain) registered for path 'speechbrain'
# Cloning into '/content/mpl-mdd/speechbrain'...
# Submodule path 'speechbrain': checked out 'a262a187c7210eca67f68c45d8dacebf51bb5442'

# %%
# !pip uninstall conda pytest -y
# !pip install "ruamel-yaml<0.18"
# !pip install "pluggy<1.0,>=0.12"
# Out:
# Found existing installation: conda 23.5.2
# Uninstalling conda-23.5.2:
#   Successfully uninstalled conda-23.5.2
# WARNING: Skipping pytest as it is not installed.
# ...
#   Attempting uninstall: pluggy
#     Found existing installation: pluggy 1.0.0
#     Uninstalling pluggy-1.0.0:
#       Successfully uninstalled pluggy-1.0.0
# ...

# %%
# !cd /content/mpl-mdd/speechbrain && pip3 install -r requirements.txt
# Out:
# Ignoring SoundFile: markers 'sys_platform == "win32"' don't match your environment
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.5/97.5 kB 4.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.9/69.9 kB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.2/51.2 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.7/246.7 kB 22.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 10.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 450.5/450.5 kB 42.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 36.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.5/19.5 MB 73.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 218.7/218.7 kB 29.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 36.3 MB/s eta 0:00:00
# ...

# %%
# !pip install textgrid transformers librosa
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 40.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.1/260.1 kB 28.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 55.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 436.1/436.1 kB 38.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 48.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 56.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 53.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.6/64.6 kB 3.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 36.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.9/377.9 kB 40.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 MB 30.5 MB/s eta 0:00:00
# ...

# %%
# !export PYTHONPATH=$PYTHONPATH:/content/mpl-mdd/speechbrain/speechbrain

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -q /content/drive/MyDrive/project_folder/l2arctic_release_v5.0.zip -d /content/L2arctic

# %%
import sys
sys.path.append('/content/mpl-mdd/speechbrain')

# %%
import sys
sys.path.append('/usr/local/lib/python3.9/site-packages')

# %%
# !pip install hyperpyyaml

# %%
from speechbrain.dataio.dataio import read_audio

# %%
sys.path.append('/content/mpl-mdd/speechbrain')

# %%
# !which python
# !python -m pip show speechbrain
# Out:
# /usr/local/bin/python
# WARNING: Package(s) not found: speechbrain

# %%
# !python --version
# Out:
# Python 3.9.17

# %%
# !pip install speechbrain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 824.8/824.8 kB 23.1 MB/s eta 0:00:00
# ...

# %%
# !pip install "numpy<2"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 34.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ...

# %%
# !pip install --upgrade speechbrain torchaudio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 43.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.5/906.5 MB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 77.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.6/134.6 kB 19.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 63.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 68.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 87.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 29.6 MB/s eta 0:00:00
# ...

# %%
import glob
import os

zip_files = glob.glob('/content/L2arctic/*.zip')
for zip_file in zip_files:
    os.system(f"unzip {zip_file} -d /content/L2arctic_data")

# %%
# !pip install speechbrain==0.5.14
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.0/519.0 kB 15.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: speechbrain
#     Found existing installation: speechbrain 1.0.2
#     Uninstalling speechbrain-1.0.2:
#       Successfully uninstalled speechbrain-1.0.2
# ...

# %%
# for labeled samples - get train.json and test.json
# !cd /content/mpl-mdd && python /content/mpl-mdd/l2arctic_prepare.py /content/L2arctic_data

# for unlabled samples - get train_unlabeled.json
# !cd /content/mpl-mdd && python /content/mpl-mdd/l2arctic_unlabeled_prepare.py /content/L2arctic_data

# split dev set from training - get train-train.json and train-dev.json
# !cd /content/mpl-mdd && python split_train_dev.py --in_json=data/train.json --out_json_train=data/train-train.json --out_json_dev=data/train-dev.json
# Out:
# Creating data/train.json
# data/train.json successfully created!
# Creating data/test.json
# data/test.json successfully created!
# Creating data/train_unlabeled.json
# data/train_unlabeled.json successfully created!

# %%
# !pip install torchvision
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 50.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 48.9 MB/s eta 0:00:00
# ...

# %%
# !pip install librosa==0.9.2
# !pip install transformers==4.25.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.3/214.3 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 47.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: librosa
#     Found existing installation: librosa 0.10.2.post1
#     Uninstalling librosa-0.10.2.post1:
#       Successfully uninstalled librosa-0.10.2.post1
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 40.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 29.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.21.0
#     Uninstalling tokenizers-0.21.0:
#       Successfully uninstalled tokenizers-0.21.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.47.1
#     Uninstalling transformers-4.47.1:
#       Successfully uninstalled transformers-4.47.1
# ...

# %%
# !cd /content/mpl-mdd && python train.py hparams/train.yaml
# Out:
# /usr/local/lib/python3.9/site-packages/huggingface_hub/file_download.py:795: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/transformers/configuration_utils.py:369: UserWarning: Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 Transformers. Using `model.gradient_checkpointing_enable()` instead, or if you are using the `Trainer` API, pass `gradient_checkpointing=True` in your `TrainingArguments`.
#   warnings.warn(
# ...

# %%
# !cd /content/mpl-mdd && python train_mpl.py hparams/train_mpl.yaml
# Out:
# /usr/local/lib/python3.9/site-packages/huggingface_hub/file_download.py:795: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.9/site-packages/transformers/configuration_utils.py:369: UserWarning: Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 Transformers. Using `model.gradient_checkpointing_enable()` instead, or if you are using the `Trainer` API, pass `gradient_checkpointing=True` in your `TrainingArguments`.
#   warnings.warn(
# ...

# %%
# !!cd /content/mpl-mdd && python evaluate.py hparams/evaluate.yaml
# Out:
# ['/usr/local/lib/python3.9/site-packages/huggingface_hub/file_download.py:795: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.',
#  '  warnings.warn(',
#  '/usr/local/lib/python3.9/site-packages/transformers/configuration_utils.py:369: UserWarning: Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 Transformers. Using `model.gradient_checkpointing_enable()` instead, or if you are using the `Trainer` API, pass `gradient_checkpointing=True` in your `TrainingArguments`.',
#  '  warnings.warn(',
# ...

# %% [markdown]
# Despite that this project was constructed well, the colab python enviroment is truly a problem to alter. Anyway we have come to the end so here goes my brief conclusion:
#
# 1.The training process was basically remained the same with official procedure. Exept for the epoch number which was reduced because I cannot afford that much of computing resource of colab... So basically I changed epoch number in train.yaml and stopped the train_mpl in advance, to save time on this procedure.
#
# 2.The results of he experiment is about to reach the result posted in the paper.Which is promising, for I studied this paper to implement it in my own master degree project. Especially the PER has reached around 15%, I wonder whether I could implement it on L2 Russian dataset I have been working with.
#
# 3.In other ways, perhaps a attention mechanism could also be used?
